# %% [markdown]
# <a href="https://colab.research.google.com/github/moroq2/AI-2024-S2/blob/main/2024_S2_mobilenetv2_r5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #画像データに対して、10種類のラベルの1つを割り当てるモデルを作成していただきます
#
# 画像認識とは、画像および動画から文字や顔などのオブジェクトや特徴を認識し検出するパターン認識技術の一分野です。特に画像に対してラベルを割り当てる画像分類は画像認識の領域においてポピュラーな研究分野となっていて、最近は深層学習が圧倒的な精度を達成しています。今回は犬や猫などの動物や車などの無機物が写った画像に対して10種類のラベルから一つ割り当てる問題に挑戦していただきます。
#
# 本コンペを活用して、データ解析・モデル構築を体験してください。
#
# データ概要
#
# 課題種別：分類
# データ種別：画像
# 学習データサンプル数：5,000
# 画像の大きさ：96×96

# %%
# ========================================
# Google Colab 上で GPU を使用する想定
# ========================================

# 1. Google Drive をマウント
from google.colab import drive
drive.mount('/content/drive')

# 2. 日本語表示のためのライブラリをインストール＆インポート
# !pip install japanize_matplotlib
import japanize_matplotlib

# 3. GPUが利用可能か確認
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# 4. 混合精度学習(Mixed Precision)の設定
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')
print("Mixed Precision Policy: ", tf.keras.mixed_precision.global_policy())

# 5. ファイルパスの設定
base_dir = "/content/drive/MyDrive/Colab Notebooks/AI_2024_S2"

# 6. 必要なライブラリのインポート
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
# MobileNetV2 をインポート
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input as preprocess_mobilenet
from tensorflow.keras.activations import swish
from tensorflow.keras.losses import CategoricalCrossentropy

# !pip install scikit-learn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# 7. データの準備（解凍＆ファイルコピー）
if not os.path.exists("train_images"):
    os.system(f"unzip -q '{base_dir}/train_images.zip'")
    os.system(f"unzip -q '{base_dir}/test_images.zip'")
    # !cp "{base_dir}/label_master.tsv" .
    # !cp "{base_dir}/sample_submit.tsv" .
    # !cp "{base_dir}/train_master.tsv" .

train_master = pd.read_csv('train_master.tsv', sep='\t')
label_master = pd.read_csv('label_master.tsv', sep='\t')
train_master['label_id'] = train_master['label_id'].astype(str)

# =========================================================
# 8. データ前処理＆学習・検証用ジェネレータの作成
#    （ラベル毎にバランス良くデータを分割する）
# =========================================================

def create_generators(preprocess_func, batch_size=400, target_size=(96, 96), test_size=0.2):
    """
    画像の基本的な前処理ジェネレータ（データ拡張あり）
    ラベルが均等になるように分割する
    """
    train_df, val_df = train_test_split(
        train_master,
        test_size=test_size,
        random_state=42,
        stratify=train_master['label_id']
    )

    # 学習用のImageDataGenerator（データ拡張を付与）
    datagen_train = ImageDataGenerator(
        rotation_range=90,          # 回転角度を最大45度まで拡張
        width_shift_range=0.1,      # 水平移動を画像幅の20%まで
        height_shift_range=0.1,     # 垂直移動を画像高さの20%まで
        #shear_range=0.1,            # せん断変換
        #zoom_range=[0.8, 1.2],      # ズームイン/ズームアウト
        horizontal_flip=True,       # 水平反転を有効化
        #vertical_flip=True,         # 垂直反転を有効化
        #brightness_range=[0.5, 1.5],# 明るさの変動幅
        channel_shift_range=20.0,   # チャネル方向の明るさシフト
        #fill_mode='reflect',        # 拡張時の画素埋め設定
        preprocessing_function=preprocess_func
    )

    # バリデーション用のImageDataGenerator（データ拡張なし）
    datagen_val = ImageDataGenerator(
        preprocessing_function=preprocess_func
    )

    train_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=42
    )

    val_generator = datagen_val.flow_from_dataframe(
        dataframe=val_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=42
    )

    return train_generator, val_generator

# =========================================================
# 9. モデル構築（MobileNetV2 + カスタム分類ヘッド）
#    （Swish活性化, BatchNormalization, Dropout採用）
# =========================================================

def build_mobilenetv2_model(input_shape=(96, 96, 3), num_classes=10, train_base=False):
    """
    MobileNetV2 をベースとした転移学習モデルの構築 (入力サイズ: 96x96)
    train_base=Falseならベースを凍結、Trueならファインチューニング可能
    """
    base_model = MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    # ベースモデルの凍結設定
    for layer in base_model.layers:
        layer.trainable = train_base

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(1024, activation=swish)(x)  # Swish活性化
    x = Dropout(0.4)(x)
    # 出力層はfloat32にキャスト（Mixed Precision環境下で安定動作のため）
    outputs = Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    return model

# =========================================================
# 10. 損失関数を変更（Focal Loss → CategoricalCrossentropy）
#     ※ ラベル平滑化を適用
# =========================================================
loss_fn = CategoricalCrossentropy(label_smoothing=0.1)

# =========================================================
# 11. モデルコンパイル・学習
# =========================================================

# ジェネレータ作成（MobileNetV2用の前処理関数を指定）
train_gen, val_gen = create_generators(
    preprocess_func=preprocess_mobilenet,
    batch_size=400,
    target_size=(96, 96),
    test_size=0.2
)

# モデル構築（初期学習時はベースは凍結）
model = build_mobilenetv2_model(
    input_shape=(96, 96, 3),
    num_classes=10,
    train_base=False
)

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_mobilenetv2_96.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=50,
    callbacks=callbacks
)

# 学習過程の可視化（損失）
plt.figure()
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('学習: 損失の推移')
plt.legend()
plt.show()

# 学習過程の可視化（精度）
plt.figure()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('学習: 精度の推移')
plt.legend()
plt.show()

# ---------------------------------------------------------
# 12. ファインチューニング（最後の数十層を解凍）
#    例として最後の30層を解凍する場合
# ---------------------------------------------------------
for layer in model.layers[-50:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

fine_tune_callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_mobilenetv2_96_finetuned.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history_fine = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=30,
    callbacks=fine_tune_callbacks
)

plt.figure()
plt.plot(history_fine.history['loss'], label='train_loss')
plt.plot(history_fine.history['val_loss'], label='val_loss')
plt.title('ファインチューニング: 損失推移')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_fine.history['accuracy'], label='train_accuracy')
plt.plot(history_fine.history['val_accuracy'], label='val_accuracy')
plt.title('ファインチューニング: 精度推移')
plt.legend()
plt.show()

# =========================================================
# ★ バリデーションデータで予測し、ヒートマップ（混同行列）を表示する処理
# =========================================================

best_model = load_model(
    'best_model_mobilenetv2_96_finetuned.keras',
    custom_objects={'swish': swish}
)

val_gen.reset()
val_predictions = best_model.predict(val_gen, steps=len(val_gen), verbose=1)
val_predicted_classes = np.argmax(val_predictions, axis=1)

true_classes = val_gen.classes
cm = confusion_matrix(true_classes, val_predicted_classes)

plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('バリデーションデータにおける混同行列')
plt.colorbar()

num_classes = 10
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, [str(i) for i in range(num_classes)], rotation=45)
plt.yticks(tick_marks, [str(i) for i in range(num_classes)])

for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, str(cm[i, j]),
                 ha='center', va='center', color='black')

plt.ylabel('正解ラベル')
plt.xlabel('予測ラベル')
plt.tight_layout()
plt.show()

# =========================================================
# 13. テストデータでの推論
#    => 最良モデルをロードして使用
# =========================================================

test_filenames = os.listdir("test_images")
test_df = pd.DataFrame({'file_name': test_filenames})

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_mobilenet
)
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory="test_images",
    x_col='file_name',
    y_col=None,
    target_size=(96, 96),
    batch_size=400,
    class_mode=None,
    shuffle=False
)

predictions = best_model.predict(
    test_generator,
    steps=len(test_generator),
    verbose=1
)

predicted_classes = np.argmax(predictions, axis=1)

submission = pd.DataFrame({
    'file_name': test_filenames,
    'label_id': predicted_classes
})

# ソート用にファイル名の数字部分を抽出
submission['file_num'] = submission['file_name'].str.extract(r'(\d+)').astype(int)
submission = submission.sort_values(by='file_num').drop(columns='file_num')

output_filename = f'{base_dir}/submission_mobilenetv2_96_0403_r0.tsv'
submission.to_csv(output_filename, sep='\t', index=False, header=False)
print(f"提出用ファイル {output_filename} を作成しました。")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: japanize_matplotlib in /usr/local/lib/python3.11/dist-packages (1.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
# Num GPUs Available:  1
# Mixed Precision Policy:  <DTypePolicy "mixed_float16">
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Found 4000 validated image filenames belonging to 10 classes.
# Found 1000 validated image filenames belonging to 10 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.1537 - loss: 2.5845 - val_accuracy: 0.4913 - val_loss: 1.7752 - learning_rate: 1.0000e-04
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.4512 - loss: 1.7335 - val_accuracy: 0.7513 - val_loss: 1.2896 - learning_rate: 1.0000e-04
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.6160 - loss: 1.4010 - val_accuracy: 0.8275 - val_loss: 1.0585 - learning_rate: 1.0000e-04
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.6723 - loss: 1.2738 - val_accuracy: 0.8600 - val_loss: 0.9541 - learning_rate: 1.0000e-04
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7009 - loss: 1.2418 - val_accuracy: 0.8725 - val_loss: 0.9057 - learning_rate: 1.0000e-04
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7355 - loss: 1.1657 - val_accuracy: 0.8712 - val_loss: 0.8794 - learning_rate: 1.0000e-04
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7353 - loss: 1.1665 - val_accuracy: 0.8800 - val_loss: 0.8594 - learning_rate: 1.0000e-04
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7614 - loss: 1.1086 - val_accuracy: 0.8788 - val_loss: 0.8503 - learning_rate: 1.0000e-04
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7527 - loss: 1.1146 - val_accuracy: 0.8888 - val_loss: 0.8411 - learning_rate: 1.0000e-04
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7761 - loss: 1.0667 - val_accuracy: 0.8925 - val_loss: 0.8302 - learning_rate: 1.0000e-04
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7749 - loss: 1.0600 - val_accuracy: 0.8963 - val_loss: 0.8184 - learning_rate: 1.0000e-04
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7647 - loss: 1.0667 - val_accuracy: 0.9075 - val_loss: 0.8103 - learning_rate: 1.0000e-04
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7838 - loss: 1.0565 - val_accuracy: 0.9013 - val_loss: 0.8071 - learning_rate: 1.0000e-04
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7862 - loss: 1.0323 - val_accuracy: 0.9087 - val_loss: 0.8047 - learning_rate: 1.0000e-04
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7789 - loss: 1.0600 - val_accuracy: 0.9125 - val_loss: 0.8017 - learning_rate: 1.0000e-04
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7899 - loss: 1.0124 - val_accuracy: 0.9100 - val_loss: 0.7988 - learning_rate: 1.0000e-04
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7970 - loss: 1.0136 - val_accuracy: 0.9137 - val_loss: 0.7967 - learning_rate: 1.0000e-04
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8193 - loss: 0.9937 - val_accuracy: 0.9150 - val_loss: 0.7942 - learning_rate: 1.0000e-04
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8066 - loss: 1.0024 - val_accuracy: 0.9100 - val_loss: 0.7935 - learning_rate: 1.0000e-04
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8051 - loss: 0.9990 - val_accuracy: 0.9162 - val_loss: 0.7925 - learning_rate: 1.0000e-04
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8087 - loss: 0.9864 - val_accuracy: 0.9137 - val_loss: 0.7886 - learning_rate: 1.0000e-04
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8142 - loss: 0.9762 - val_accuracy: 0.9137 - val_loss: 0.7863 - learning_rate: 1.0000e-04
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8038 - loss: 0.9869 - val_accuracy: 0.9100 - val_loss: 0.7867 - learning_rate: 1.0000e-04
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8097 - loss: 0.9987 - val_accuracy: 0.9075 - val_loss: 0.7867 - learning_rate: 1.0000e-04
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8095 - loss: 0.9669 - val_accuracy: 0.9137 - val_loss: 0.7868 - learning_rate: 1.0000e-04
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8184 - loss: 0.9766 - val_accuracy: 0.9125 - val_loss: 0.7870 - learning_rate: 1.0000e-05
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8268 - loss: 0.9537 - val_accuracy: 0.9112 - val_loss: 0.7871 - learning_rate: 1.0000e-05
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8284 - loss: 0.9516 - val_accuracy: 0.9125 - val_loss: 0.7873 - learning_rate: 1.0000e-05
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8354 - loss: 0.9463 - val_accuracy: 0.9100 - val_loss: 0.7875 - learning_rate: 1.0000e-05
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8263 - loss: 0.9557 - val_accuracy: 0.9075 - val_loss: 0.7877 - learning_rate: 1.0000e-05
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8173 - loss: 0.9726 - val_accuracy: 0.9075 - val_loss: 0.7876 - learning_rate: 1.0000e-05
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.7457 - loss: 1.1589 - val_accuracy: 0.9050 - val_loss: 0.8056 - learning_rate: 1.0000e-04
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8088 - loss: 1.0080 - val_accuracy: 0.9100 - val_loss: 0.8117 - learning_rate: 1.0000e-04
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8272 - loss: 0.9785 - val_accuracy: 0.9100 - val_loss: 0.7954 - learning_rate: 1.0000e-04
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8333 - loss: 0.9511 - val_accuracy: 0.9025 - val_loss: 0.7873 - learning_rate: 1.0000e-04
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8453 - loss: 0.9307 - val_accuracy: 0.9000 - val_loss: 0.7853 - learning_rate: 1.0000e-04
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8594 - loss: 0.8893 - val_accuracy: 0.9062 - val_loss: 0.7829 - learning_rate: 1.0000e-04
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8705 - loss: 0.8665 - val_accuracy: 0.8988 - val_loss: 0.7913 - learning_rate: 1.0000e-04
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8819 - loss: 0.8513 - val_accuracy: 0.9025 - val_loss: 0.7882 - learning_rate: 1.0000e-04
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8918 - loss: 0.8321 - val_accuracy: 0.9038 - val_loss: 0.7788 - learning_rate: 1.0000e-04
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8910 - loss: 0.8276 - val_accuracy: 0.9038 - val_loss: 0.7816 - learning_rate: 1.0000e-04
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8979 - loss: 0.8056 - val_accuracy: 0.8925 - val_loss: 0.8003 - learning_rate: 1.0000e-04
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8873 - loss: 0.8142 - val_accuracy: 0.8963 - val_loss: 0.7990 - learning_rate: 1.0000e-04
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8949 - loss: 0.8123 - val_accuracy: 0.8938 - val_loss: 0.7999 - learning_rate: 1.0000e-05
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9068 - loss: 0.7871 - val_accuracy: 0.8938 - val_loss: 0.7997 - learning_rate: 1.0000e-05
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9003 - loss: 0.7901 - val_accuracy: 0.8975 - val_loss: 0.7991 - learning_rate: 1.0000e-05
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9094 - loss: 0.7797 - val_accuracy: 0.8975 - val_loss: 0.7999 - learning_rate: 1.0000e-05
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9029 - loss: 0.7891 - val_accuracy: 0.8988 - val_loss: 0.8024 - learning_rate: 1.0000e-05
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9037 - loss: 0.7938 - val_accuracy: 0.9000 - val_loss: 0.8034 - learning_rate: 1.0000e-05
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step
# Found 8000 validated image filenames.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 210ms/step
# 提出用ファイル /content/drive/MyDrive/Colab Notebooks/AI_2024_S2/submission_mobilenetv2_96_0403_r0.tsv を作成しました。
