# %% [markdown]
# <a href="https://colab.research.google.com/github/moroq2/AI-2024-S2/blob/main/2024_s2_ConvNeXtLarge_r14_ipyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #画像データに対して、10種類のラベルの1つを割り当てるモデルを作成していただきます
#
# 画像認識とは、画像および動画から文字や顔などのオブジェクトや特徴を認識し検出するパターン認識技術の一分野です。特に画像に対してラベルを割り当てる画像分類は画像認識の領域においてポピュラーな研究分野となっていて、最近は深層学習が圧倒的な精度を達成しています。今回は犬や猫などの動物や車などの無機物が写った画像に対して10種類のラベルから一つ割り当てる問題に挑戦していただきます。
#
# 本コンペを活用して、データ解析・モデル構築を体験してください。
#
# データ概要
#
# 課題種別：分類
# データ種別：画像
# 学習データサンプル数：5,000
# 画像の大きさ：96×96

# %%
# ========================================
# Google Colab 上で GPU を使用する想定
# ========================================

# 1. Google Drive をマウント
from google.colab import drive
drive.mount('/content/drive')

# 2. 日本語表示のためのライブラリをインストール＆インポート
# !pip install japanize_matplotlib
import japanize_matplotlib

# 3. GPUが利用可能か確認
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# 4. 混合精度学習(Mixed Precision)の設定
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')
print("Mixed Precision Policy: ", tf.keras.mixed_precision.global_policy())

# 5. ファイルパスの設定
base_dir = "/content/drive/MyDrive/Colab Notebooks/AI_2024_S2"

# 6. 必要なライブラリのインポート
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.convnext import ConvNeXtLarge, preprocess_input as preprocess_convnext
from tensorflow.keras.activations import swish
from tensorflow.keras.losses import CategoricalCrossentropy

# !pip install scikit-learn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# 7. データの準備（解凍＆ファイルコピー）
if not os.path.exists("train_images"):
    os.system(f"unzip -q '{base_dir}/train_images.zip'")
    os.system(f"unzip -q '{base_dir}/test_images.zip'")
    # !cp "{base_dir}/label_master.tsv" .
    # !cp "{base_dir}/sample_submit.tsv" .
    # !cp "{base_dir}/train_master.tsv" .

train_master = pd.read_csv('train_master.tsv', sep='\t')
label_master = pd.read_csv('label_master.tsv', sep='\t')
train_master['label_id'] = train_master['label_id'].astype(str)

# =========================================================
# 8. データ前処理＆学習・検証用ジェネレータの作成
#    （ラベル毎にバランス良くデータを分割する）
# =========================================================

def create_generators(preprocess_func, batch_size=20, target_size=(224, 224), test_size=0.2):
    """
    画像の基本的な前処理ジェネレータ（データ拡張あり）
    ラベルが均等になるように分割する
    """
    train_df, val_df = train_test_split(
        train_master,
        test_size=test_size,
        random_state=42,
        stratify=train_master['label_id']
    )

    # 学習用のImageDataGenerator（データ拡張を付与）
    datagen_train = ImageDataGenerator(
        rotation_range=30,          # 回転角度を最大90度まで拡張
        width_shift_range=0.1,      # 水平移動を画像幅の10%まで
        height_shift_range=0.1,     # 垂直移動を画像高さの10%まで
        shear_range=0.2,            # せん断変換
        zoom_range=[0.8, 1.2],      # ズームイン/ズームアウト
        horizontal_flip=True,       # 水平反転を有効化
        vertical_flip=True,         # 垂直反転を有効化
        brightness_range=[0.5, 1.5],# 明るさの変動幅
        channel_shift_range=50.0,   # チャネル方向の明るさシフト
        fill_mode='reflect',        # 拡張時の画素埋め設定
        preprocessing_function=preprocess_func
    )

    # バリデーション用のImageDataGenerator（データ拡張なし）
    datagen_val = ImageDataGenerator(
        preprocessing_function=preprocess_func
    )

    train_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=42
    )

    val_generator = datagen_val.flow_from_dataframe(
        dataframe=val_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=42
    )

    return train_generator, val_generator

# =========================================================
# 9. モデル構築（ConvNeXtLarge + カスタム分類ヘッド）
#    （Swish活性化, BatchNormalization, Dropout採用）
# =========================================================

def build_convnext_model(input_shape=(224, 224, 3), num_classes=10, train_base=False):
    """
    ConvNeXtLarge をベースとした転移学習モデルの構築 (入力サイズ: 224x224)
    train_base=Falseならベースを凍結、Trueならファインチューニング可能
    """
    base_model = ConvNeXtLarge(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    # ベースモデルの凍結設定
    for layer in base_model.layers:
        layer.trainable = train_base

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    # 変更：Dense(256, activation=swish) → Dense(1024, activation=swish)
    x = Dense(1024, activation=swish)(x)
    x = Dropout(0.4)(x)
    # 出力層はfloat32にキャスト（Mixed Precision環境下で安定動作のため）
    outputs = Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    return model

# =========================================================
# 10. 損失関数を変更（Focal Loss → CategoricalCrossentropy）
#     ※ ラベル平滑化を適用
# =========================================================
loss_fn = CategoricalCrossentropy(label_smoothing=0.1)

# =========================================================
# 11. モデルコンパイル・学習
# =========================================================

# ジェネレータ作成（ConvNeXt用の前処理関数を指定）
train_gen, val_gen = create_generators(
    preprocess_func=preprocess_convnext,
    batch_size=20,
    target_size=(224, 224),
    test_size=0.2
)

# モデル構築（初期学習時はベースは凍結）
model = build_convnext_model(
    input_shape=(224, 224, 3),
    num_classes=10,
    train_base=False
)

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_convnextlarge_224.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=50,
    callbacks=callbacks
)

# 学習過程の可視化（損失）
plt.figure()
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('学習: 損失の推移')
plt.legend()
plt.show()

# 学習過程の可視化（精度）
plt.figure()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('学習: 精度の推移')
plt.legend()
plt.show()

# ---------------------------------------------------------
# 12. ファインチューニング（最後の20層を解凍）
# ---------------------------------------------------------
for layer in model.layers[-50:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

fine_tune_callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_convnextlarge_224_finetuned.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history_fine = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=50,
    callbacks=fine_tune_callbacks
)

plt.figure()
plt.plot(history_fine.history['loss'], label='train_loss')
plt.plot(history_fine.history['val_loss'], label='val_loss')
plt.title('ファインチューニング: 損失推移')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_fine.history['accuracy'], label='train_accuracy')
plt.plot(history_fine.history['val_accuracy'], label='val_accuracy')
plt.title('ファインチューニング: 精度推移')
plt.legend()
plt.show()

# =========================================================
# ★ バリデーションデータで予測し、ヒートマップ（混同行列）を表示する処理
# =========================================================

best_model = load_model(
    'best_model_convnextlarge_224_finetuned.keras',
    custom_objects={'swish': swish}
)
# バリデーションデータに対する評価（loss, accuracy の計算）
val_gen.reset()
val_loss, val_accuracy = best_model.evaluate(val_gen, steps=len(val_gen), verbose=1)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")

val_gen.reset()
val_predictions = best_model.predict(val_gen, steps=len(val_gen), verbose=1)
val_predicted_classes = np.argmax(val_predictions, axis=1)

true_classes = val_gen.classes
cm = confusion_matrix(true_classes, val_predicted_classes)

plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('バリデーションデータにおける混同行列')
plt.colorbar()

num_classes = 10
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, [str(i) for i in range(num_classes)], rotation=45)
plt.yticks(tick_marks, [str(i) for i in range(num_classes)])

for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, str(cm[i, j]),
                 ha='center', va='center', color='black')

plt.ylabel('正解ラベル')
plt.xlabel('予測ラベル')
plt.tight_layout()
plt.show()

# =========================================================
# 13. テストデータでの推論
#    => 最良モデルをロードして使用
# =========================================================

test_filenames = os.listdir("test_images")
test_df = pd.DataFrame({'file_name': test_filenames})

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_convnext
)
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory="test_images",
    x_col='file_name',
    y_col=None,
    target_size=(224,224),
    batch_size=20,
    class_mode=None,
    shuffle=False
)

predictions = best_model.predict(
    test_generator,
    steps=len(test_generator),
    verbose=1
)

predicted_classes = np.argmax(predictions, axis=1)

submission = pd.DataFrame({
    'file_name': test_filenames,
    'label_id': predicted_classes
})

# ソート用にファイル名の数字部分を抽出
submission['file_num'] = submission['file_name'].str.extract(r'(\d+)').astype(int)
submission = submission.sort_values(by='file_num').drop(columns='file_num')

output_filename = f'{base_dir}/submission_convnextlarge_224_0405_r0.tsv'
submission.to_csv(output_filename, sep='\t', index=False, header=False)
print(f"提出用ファイル {output_filename} を作成しました。")
# Out:
# Mounted at /content/drive
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 101.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=d5894f1a16f4231d9792fc9583afd6657a374bef878060ec86a973f15db4a907
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3
# Num GPUs Available:  1
# Mixed Precision Policy:  <DTypePolicy "mixed_float16">
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Found 4000 validated image filenames belonging to 10 classes.
# Found 1000 validated image filenames belonging to 10 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_large_notop.h5
# 785596384/785596384 ━━━━━━━━━━━━━━━━━━━━ 34s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 102s 327ms/step - accuracy: 0.5972 - loss: 1.5323 - val_accuracy: 0.9780 - val_loss: 0.6209 - learning_rate: 1.0000e-04
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 263ms/step - accuracy: 0.8636 - loss: 0.8835 - val_accuracy: 0.9810 - val_loss: 0.6260 - learning_rate: 1.0000e-04
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 285ms/step - accuracy: 0.8935 - loss: 0.8397 - val_accuracy: 0.9830 - val_loss: 0.6208 - learning_rate: 1.0000e-04
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 264ms/step - accuracy: 0.9044 - loss: 0.8026 - val_accuracy: 0.9820 - val_loss: 0.6320 - learning_rate: 1.0000e-04
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - accuracy: 0.9095 - loss: 0.7835 - val_accuracy: 0.9810 - val_loss: 0.6230 - learning_rate: 1.0000e-04
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - accuracy: 0.9276 - loss: 0.7478 - val_accuracy: 0.9850 - val_loss: 0.6237 - learning_rate: 1.0000e-04
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 284ms/step - accuracy: 0.9286 - loss: 0.7523 - val_accuracy: 0.9850 - val_loss: 0.6185 - learning_rate: 1.0000e-05
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 287ms/step - accuracy: 0.9270 - loss: 0.7618 - val_accuracy: 0.9850 - val_loss: 0.6144 - learning_rate: 1.0000e-05
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 284ms/step - accuracy: 0.9326 - loss: 0.7381 - val_accuracy: 0.9850 - val_loss: 0.6132 - learning_rate: 1.0000e-05
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 286ms/step - accuracy: 0.9387 - loss: 0.7274 - val_accuracy: 0.9850 - val_loss: 0.6116 - learning_rate: 1.0000e-05
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 285ms/step - accuracy: 0.9347 - loss: 0.7317 - val_accuracy: 0.9850 - val_loss: 0.6083 - learning_rate: 1.0000e-05
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - accuracy: 0.9355 - loss: 0.7284 - val_accuracy: 0.9830 - val_loss: 0.6087 - learning_rate: 1.0000e-05
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 282ms/step - accuracy: 0.9399 - loss: 0.7280 - val_accuracy: 0.9840 - val_loss: 0.6056 - learning_rate: 1.0000e-05
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 285ms/step - accuracy: 0.9371 - loss: 0.7248 - val_accuracy: 0.9830 - val_loss: 0.6047 - learning_rate: 1.0000e-05
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 285ms/step - accuracy: 0.9286 - loss: 0.7350 - val_accuracy: 0.9830 - val_loss: 0.6032 - learning_rate: 1.0000e-05
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 285ms/step - accuracy: 0.9407 - loss: 0.7233 - val_accuracy: 0.9830 - val_loss: 0.6031 - learning_rate: 1.0000e-05
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.9384 - loss: 0.7247 - val_accuracy: 0.9840 - val_loss: 0.6026 - learning_rate: 1.0000e-05
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 55s 274ms/step - accuracy: 0.9249 - loss: 0.7448 - val_accuracy: 0.9830 - val_loss: 0.6037 - learning_rate: 1.0000e-05
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 55s 274ms/step - accuracy: 0.9229 - loss: 0.7366 - val_accuracy: 0.9830 - val_loss: 0.6028 - learning_rate: 1.0000e-05
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 295ms/step - accuracy: 0.9429 - loss: 0.7214 - val_accuracy: 0.9830 - val_loss: 0.6012 - learning_rate: 1.0000e-05
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9382 - loss: 0.7181 - val_accuracy: 0.9840 - val_loss: 0.5988 - learning_rate: 1.0000e-05
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 270ms/step - accuracy: 0.9339 - loss: 0.7350 - val_accuracy: 0.9830 - val_loss: 0.5994 - learning_rate: 1.0000e-05
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 271ms/step - accuracy: 0.9393 - loss: 0.7148 - val_accuracy: 0.9830 - val_loss: 0.5999 - learning_rate: 1.0000e-05
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9421 - loss: 0.7150 - val_accuracy: 0.9830 - val_loss: 0.5985 - learning_rate: 1.0000e-05
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.9403 - loss: 0.7199 - val_accuracy: 0.9830 - val_loss: 0.5983 - learning_rate: 1.0000e-05
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 271ms/step - accuracy: 0.9407 - loss: 0.7156 - val_accuracy: 0.9820 - val_loss: 0.5993 - learning_rate: 1.0000e-05
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 287ms/step - accuracy: 0.9437 - loss: 0.7030 - val_accuracy: 0.9830 - val_loss: 0.5980 - learning_rate: 1.0000e-05
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.9416 - loss: 0.7086 - val_accuracy: 0.9830 - val_loss: 0.5972 - learning_rate: 1.0000e-05
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 286ms/step - accuracy: 0.9529 - loss: 0.7023 - val_accuracy: 0.9840 - val_loss: 0.5968 - learning_rate: 1.0000e-05
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9465 - loss: 0.7119 - val_accuracy: 0.9830 - val_loss: 0.5954 - learning_rate: 1.0000e-05
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 266ms/step - accuracy: 0.9488 - loss: 0.6989 - val_accuracy: 0.9830 - val_loss: 0.5981 - learning_rate: 1.0000e-05
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 269ms/step - accuracy: 0.9532 - loss: 0.6926 - val_accuracy: 0.9830 - val_loss: 0.5959 - learning_rate: 1.0000e-05
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.9502 - loss: 0.6943 - val_accuracy: 0.9820 - val_loss: 0.5949 - learning_rate: 1.0000e-05
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 270ms/step - accuracy: 0.9398 - loss: 0.7109 - val_accuracy: 0.9830 - val_loss: 0.5958 - learning_rate: 1.0000e-05
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 266ms/step - accuracy: 0.9467 - loss: 0.7094 - val_accuracy: 0.9830 - val_loss: 0.5961 - learning_rate: 1.0000e-05
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.9503 - loss: 0.6949 - val_accuracy: 0.9830 - val_loss: 0.5947 - learning_rate: 1.0000e-05
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 287ms/step - accuracy: 0.9585 - loss: 0.6871 - val_accuracy: 0.9820 - val_loss: 0.5938 - learning_rate: 1.0000e-05
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - accuracy: 0.9520 - loss: 0.6903 - val_accuracy: 0.9820 - val_loss: 0.5939 - learning_rate: 1.0000e-05
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 287ms/step - accuracy: 0.9393 - loss: 0.7023 - val_accuracy: 0.9850 - val_loss: 0.5925 - learning_rate: 1.0000e-05
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 286ms/step - accuracy: 0.9528 - loss: 0.6962 - val_accuracy: 0.9860 - val_loss: 0.5915 - learning_rate: 1.0000e-05
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 268ms/step - accuracy: 0.9531 - loss: 0.6959 - val_accuracy: 0.9860 - val_loss: 0.5930 - learning_rate: 1.0000e-05
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 270ms/step - accuracy: 0.9506 - loss: 0.6884 - val_accuracy: 0.9850 - val_loss: 0.5920 - learning_rate: 1.0000e-05
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - accuracy: 0.9572 - loss: 0.6806 - val_accuracy: 0.9840 - val_loss: 0.5918 - learning_rate: 1.0000e-05
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 285ms/step - accuracy: 0.9394 - loss: 0.7071 - val_accuracy: 0.9840 - val_loss: 0.5910 - learning_rate: 1.0000e-05
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 266ms/step - accuracy: 0.9561 - loss: 0.6829 - val_accuracy: 0.9830 - val_loss: 0.5911 - learning_rate: 1.0000e-05
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 266ms/step - accuracy: 0.9583 - loss: 0.6737 - val_accuracy: 0.9820 - val_loss: 0.5919 - learning_rate: 1.0000e-05
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 266ms/step - accuracy: 0.9546 - loss: 0.6841 - val_accuracy: 0.9820 - val_loss: 0.5915 - learning_rate: 1.0000e-05
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9531 - loss: 0.6931 - val_accuracy: 0.9820 - val_loss: 0.5906 - learning_rate: 1.0000e-05
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9524 - loss: 0.6852 - val_accuracy: 0.9840 - val_loss: 0.5896 - learning_rate: 1.0000e-05
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 54s 271ms/step - accuracy: 0.9571 - loss: 0.6756 - val_accuracy: 0.9850 - val_loss: 0.5905 - learning_rate: 1.0000e-05
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 119s 381ms/step - accuracy: 0.9361 - loss: 0.7265 - val_accuracy: 0.9860 - val_loss: 0.6126 - learning_rate: 1.0000e-04
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 346ms/step - accuracy: 0.9486 - loss: 0.7019 - val_accuracy: 0.9800 - val_loss: 0.6022 - learning_rate: 1.0000e-04
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 72s 360ms/step - accuracy: 0.9598 - loss: 0.6803 - val_accuracy: 0.9840 - val_loss: 0.5889 - learning_rate: 1.0000e-04
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 350ms/step - accuracy: 0.9679 - loss: 0.6613 - val_accuracy: 0.9860 - val_loss: 0.5875 - learning_rate: 1.0000e-04
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 348ms/step - accuracy: 0.9733 - loss: 0.6429 - val_accuracy: 0.9900 - val_loss: 0.5819 - learning_rate: 1.0000e-04
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9732 - loss: 0.6349 - val_accuracy: 0.9860 - val_loss: 0.5821 - learning_rate: 1.0000e-04
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 344ms/step - accuracy: 0.9784 - loss: 0.6233 - val_accuracy: 0.9900 - val_loss: 0.5730 - learning_rate: 1.0000e-04
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 343ms/step - accuracy: 0.9870 - loss: 0.6024 - val_accuracy: 0.9880 - val_loss: 0.5625 - learning_rate: 1.0000e-04
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9885 - loss: 0.5945 - val_accuracy: 0.9900 - val_loss: 0.5645 - learning_rate: 1.0000e-04
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 345ms/step - accuracy: 0.9873 - loss: 0.5967 - val_accuracy: 0.9890 - val_loss: 0.5585 - learning_rate: 1.0000e-04
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 348ms/step - accuracy: 0.9870 - loss: 0.5877 - val_accuracy: 0.9910 - val_loss: 0.5538 - learning_rate: 1.0000e-04
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.9878 - loss: 0.5825 - val_accuracy: 0.9890 - val_loss: 0.5558 - learning_rate: 1.0000e-04
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 346ms/step - accuracy: 0.9927 - loss: 0.5764 - val_accuracy: 0.9860 - val_loss: 0.5534 - learning_rate: 1.0000e-04
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 342ms/step - accuracy: 0.9921 - loss: 0.5705 - val_accuracy: 0.9910 - val_loss: 0.5442 - learning_rate: 1.0000e-04
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9927 - loss: 0.5617 - val_accuracy: 0.9870 - val_loss: 0.5542 - learning_rate: 1.0000e-04
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 342ms/step - accuracy: 0.9938 - loss: 0.5662 - val_accuracy: 0.9860 - val_loss: 0.5405 - learning_rate: 1.0000e-04
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.9888 - loss: 0.5660 - val_accuracy: 0.9920 - val_loss: 0.5408 - learning_rate: 1.0000e-04
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 345ms/step - accuracy: 0.9935 - loss: 0.5567 - val_accuracy: 0.9900 - val_loss: 0.5401 - learning_rate: 1.0000e-04
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 351ms/step - accuracy: 0.9915 - loss: 0.5559 - val_accuracy: 0.9880 - val_loss: 0.5373 - learning_rate: 1.0000e-04
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 346ms/step - accuracy: 0.9940 - loss: 0.5539 - val_accuracy: 0.9890 - val_loss: 0.5367 - learning_rate: 1.0000e-04
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 345ms/step - accuracy: 0.9942 - loss: 0.5459 - val_accuracy: 0.9870 - val_loss: 0.5362 - learning_rate: 1.0000e-04
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9939 - loss: 0.5464 - val_accuracy: 0.9850 - val_loss: 0.5368 - learning_rate: 1.0000e-04
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9951 - loss: 0.5487 - val_accuracy: 0.9840 - val_loss: 0.5397 - learning_rate: 1.0000e-04
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9931 - loss: 0.5443 - val_accuracy: 0.9850 - val_loss: 0.5375 - learning_rate: 1.0000e-04
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 347ms/step - accuracy: 0.9973 - loss: 0.5367 - val_accuracy: 0.9850 - val_loss: 0.5315 - learning_rate: 1.0000e-05
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 346ms/step - accuracy: 0.9969 - loss: 0.5330 - val_accuracy: 0.9870 - val_loss: 0.5311 - learning_rate: 1.0000e-05
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 344ms/step - accuracy: 0.9975 - loss: 0.5361 - val_accuracy: 0.9860 - val_loss: 0.5300 - learning_rate: 1.0000e-05
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 353ms/step - accuracy: 0.9986 - loss: 0.5303 - val_accuracy: 0.9860 - val_loss: 0.5298 - learning_rate: 1.0000e-05
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 342ms/step - accuracy: 0.9962 - loss: 0.5310 - val_accuracy: 0.9860 - val_loss: 0.5288 - learning_rate: 1.0000e-05
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 347ms/step - accuracy: 0.9972 - loss: 0.5305 - val_accuracy: 0.9860 - val_loss: 0.5285 - learning_rate: 1.0000e-05
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9965 - loss: 0.5276 - val_accuracy: 0.9860 - val_loss: 0.5295 - learning_rate: 1.0000e-05
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 347ms/step - accuracy: 0.9973 - loss: 0.5288 - val_accuracy: 0.9860 - val_loss: 0.5282 - learning_rate: 1.0000e-05
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 344ms/step - accuracy: 0.9989 - loss: 0.5268 - val_accuracy: 0.9870 - val_loss: 0.5278 - learning_rate: 1.0000e-05
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 343ms/step - accuracy: 0.9983 - loss: 0.5280 - val_accuracy: 0.9880 - val_loss: 0.5278 - learning_rate: 1.0000e-05
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 340ms/step - accuracy: 0.9980 - loss: 0.5269 - val_accuracy: 0.9870 - val_loss: 0.5275 - learning_rate: 1.0000e-05
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9986 - loss: 0.5240 - val_accuracy: 0.9890 - val_loss: 0.5276 - learning_rate: 1.0000e-05
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.9986 - loss: 0.5230 - val_accuracy: 0.9900 - val_loss: 0.5281 - learning_rate: 1.0000e-05
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 287ms/step - accuracy: 0.9990 - loss: 0.5242 - val_accuracy: 0.9890 - val_loss: 0.5275 - learning_rate: 1.0000e-05
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.9975 - loss: 0.5265 - val_accuracy: 0.9880 - val_loss: 0.5277 - learning_rate: 1.0000e-05
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.9968 - loss: 0.5274 - val_accuracy: 0.9860 - val_loss: 0.5282 - learning_rate: 1.0000e-05
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 347ms/step - accuracy: 0.9988 - loss: 0.5211 - val_accuracy: 0.9870 - val_loss: 0.5269 - learning_rate: 1.0000e-05
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 290ms/step - accuracy: 0.9982 - loss: 0.5253 - val_accuracy: 0.9880 - val_loss: 0.5282 - learning_rate: 1.0000e-05
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9990 - loss: 0.5224 - val_accuracy: 0.9860 - val_loss: 0.5282 - learning_rate: 1.0000e-05
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9992 - loss: 0.5247 - val_accuracy: 0.9860 - val_loss: 0.5276 - learning_rate: 1.0000e-05
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 296ms/step - accuracy: 0.9985 - loss: 0.5223 - val_accuracy: 0.9880 - val_loss: 0.5271 - learning_rate: 1.0000e-05
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 287ms/step - accuracy: 0.9969 - loss: 0.5228 - val_accuracy: 0.9870 - val_loss: 0.5277 - learning_rate: 1.0000e-05
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.9986 - loss: 0.5224 - val_accuracy: 0.9890 - val_loss: 0.5271 - learning_rate: 1.0000e-05
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 288ms/step - accuracy: 0.9993 - loss: 0.5200 - val_accuracy: 0.9870 - val_loss: 0.5276 - learning_rate: 1.0000e-05
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 291ms/step - accuracy: 0.9996 - loss: 0.5198 - val_accuracy: 0.9870 - val_loss: 0.5272 - learning_rate: 1.0000e-05
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 58s 289ms/step - accuracy: 0.9983 - loss: 0.5219 - val_accuracy: 0.9870 - val_loss: 0.5280 - learning_rate: 1.0000e-05
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9939 - loss: 0.5149
# Validation Loss: 0.5269
# Validation Accuracy: 0.9870
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step
# Found 8000 validated image filenames.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step
# 提出用ファイル /content/drive/MyDrive/Colab Notebooks/AI_2024_S2/submission_convnextlarge_224_0405_r0.tsv を作成しました。
