# %% [markdown]
# <a href="https://colab.research.google.com/github/moroq2/AI-2024-S2/blob/main/2024_S2_EfficientNetV2L_r7_ipyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #画像データに対して、10種類のラベルの1つを割り当てるモデルを作成していただきます
#
# 画像認識とは、画像および動画から文字や顔などのオブジェクトや特徴を認識し検出するパターン認識技術の一分野です。特に画像に対してラベルを割り当てる画像分類は画像認識の領域においてポピュラーな研究分野となっていて、最近は深層学習が圧倒的な精度を達成しています。今回は犬や猫などの動物や車などの無機物が写った画像に対して10種類のラベルから一つ割り当てる問題に挑戦していただきます。
#
# 本コンペを活用して、データ解析・モデル構築を体験してください。
#
# データ概要
#
# 課題種別：分類
# データ種別：画像
# 学習データサンプル数：5,000
# 画像の大きさ：96×96

# %%
# ========================================
# Google Colab 上で GPU を使用する想定
# ========================================

# 1. Google Drive をマウント
from google.colab import drive
drive.mount('/content/drive')

# 2. 日本語表示のためのライブラリをインストール＆インポート
# !pip install japanize_matplotlib
import japanize_matplotlib

# 3. GPUが利用可能か確認
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# 4. 混合精度学習(Mixed Precision)の設定
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')
print("Mixed Precision Policy: ", tf.keras.mixed_precision.global_policy())

# 5. ファイルパスの設定
base_dir = "/content/drive/MyDrive/Colab Notebooks/AI_2024_S2"

# 6. 必要なライブラリのインポート
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
# EfficientNetV2L をインポート
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2L, preprocess_input as preprocess_efficientnet_v2
from tensorflow.keras.activations import swish
from tensorflow.keras.losses import CategoricalCrossentropy

# !pip install scikit-learn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# 7. データの準備（解凍＆ファイルコピー）
if not os.path.exists("train_images"):
    os.system(f"unzip -q '{base_dir}/train_images.zip'")
    os.system(f"unzip -q '{base_dir}/test_images.zip'")
    # !cp "{base_dir}/label_master.tsv" .
    # !cp "{base_dir}/sample_submit.tsv" .
    # !cp "{base_dir}/train_master.tsv" .

train_master = pd.read_csv('train_master.tsv', sep='\t')
label_master = pd.read_csv('label_master.tsv', sep='\t')
train_master['label_id'] = train_master['label_id'].astype(str)

# =========================================================
# 8. データ前処理＆学習・検証用ジェネレータの作成
#    （ラベル毎にバランス良くデータを分割する）
# =========================================================

def create_generators(preprocess_func, batch_size=20, target_size=(224, 224), test_size=0.2):
    """
    画像の基本的な前処理ジェネレータ（データ拡張あり）
    ラベルが均等になるように分割する
    """
    train_df, val_df = train_test_split(
        train_master,
        test_size=test_size,
        random_state=42,
        stratify=train_master['label_id']
    )

    # 学習用のImageDataGenerator（データ拡張を付与）
    datagen_train = ImageDataGenerator(
        rotation_range=30,          # 回転角度を最大30度まで
        width_shift_range=0.1,      # 水平移動を画像幅の10%まで
        height_shift_range=0.1,     # 垂直移動を画像高さの10%まで
        shear_range=0.2,            # せん断変換
        zoom_range=[0.8, 1.2],      # ズームイン/ズームアウト
        horizontal_flip=True,       # 水平反転を有効化
        vertical_flip=True,         # 垂直反転を有効化
        brightness_range=[0.5, 1.5],# 明るさの変動幅
        channel_shift_range=50.0,   # チャネル方向の明るさシフト
        fill_mode='reflect',        # 拡張時の画素埋め設定
        preprocessing_function=preprocess_func
    )

    # バリデーション用のImageDataGenerator（データ拡張なし）
    datagen_val = ImageDataGenerator(
        preprocessing_function=preprocess_func
    )

    train_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=42
    )

    val_generator = datagen_val.flow_from_dataframe(
        dataframe=val_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=42
    )

    return train_generator, val_generator

# =========================================================
# 9. モデル構築（EfficientNetV2L + カスタム分類ヘッド）
#    （Swish活性化, BatchNormalization, Dropout採用）
# =========================================================

def build_efficientnet_v2l_model(input_shape=(224, 224, 3), num_classes=10, train_base=False):
    """
    EfficientNetV2L をベースとした転移学習モデルの構築
    train_base=Falseならベースを凍結、Trueならファインチューニング可能
    """
    base_model = EfficientNetV2L(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    # ベースモデルの凍結設定
    for layer in base_model.layers:
        layer.trainable = train_base

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(1024, activation=swish)(x)  # Swish活性化
    x = Dropout(0.4)(x)
    # 出力層はfloat32にキャスト（Mixed Precision環境下で安定動作のため）
    outputs = Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    return model

# =========================================================
# 10. 損失関数を設定（ラベル平滑化付き CategoricalCrossentropy）
# =========================================================
loss_fn = CategoricalCrossentropy(label_smoothing=0.1)

# =========================================================
# 11. モデルコンパイル・学習
# =========================================================

# ジェネレータ作成（EfficientNetV2用の前処理関数を指定）
train_gen, val_gen = create_generators(
    preprocess_func=preprocess_efficientnet_v2,
    batch_size=20,
    target_size=(224, 224),
    test_size=0.2
)

# モデル構築（初期学習時はベースは凍結）
model = build_efficientnet_v2l_model(
    input_shape=(224, 224, 3),
    num_classes=10,
    train_base=False
)

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_efficientnetv2l_224.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=50,
    callbacks=callbacks
)

# 学習過程の可視化（損失）
plt.figure()
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('学習: 損失の推移')
plt.legend()
plt.show()

# 学習過程の可視化（精度）
plt.figure()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('学習: 精度の推移')
plt.legend()
plt.show()

# ---------------------------------------------------------
# 12. ファインチューニング（最後の50層を解凍）
# ---------------------------------------------------------
for layer in model.layers[-50:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

fine_tune_callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_efficientnetv2l_224_finetuned.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history_fine = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=30,
    callbacks=fine_tune_callbacks
)

plt.figure()
plt.plot(history_fine.history['loss'], label='train_loss')
plt.plot(history_fine.history['val_loss'], label='val_loss')
plt.title('ファインチューニング: 損失推移')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_fine.history['accuracy'], label='train_accuracy')
plt.plot(history_fine.history['val_accuracy'], label='val_accuracy')
plt.title('ファインチューニング: 精度推移')
plt.legend()
plt.show()

# =========================================================
# ★ バリデーションデータで予測し、ヒートマップ（混同行列）を表示する処理
# =========================================================

best_model = load_model(
    'best_model_efficientnetv2l_224_finetuned.keras',
    custom_objects={'swish': swish}
)
# バリデーションデータに対する評価（loss, accuracy の計算）
val_gen.reset()
val_loss, val_accuracy = best_model.evaluate(val_gen, steps=len(val_gen), verbose=1)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")

val_gen.reset()
val_predictions = best_model.predict(val_gen, steps=len(val_gen), verbose=1)
val_predicted_classes = np.argmax(val_predictions, axis=1)

true_classes = val_gen.classes
cm = confusion_matrix(true_classes, val_predicted_classes)

plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('バリデーションデータにおける混同行列')
plt.colorbar()

num_classes = 10
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, [str(i) for i in range(num_classes)], rotation=45)
plt.yticks(tick_marks, [str(i) for i in range(num_classes)])

for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, str(cm[i, j]),
                 ha='center', va='center', color='black')

plt.ylabel('正解ラベル')
plt.xlabel('予測ラベル')
plt.tight_layout()
plt.show()

# =========================================================
# 13. テストデータでの推論
#    => 最良モデルをロードして使用
# =========================================================

test_filenames = os.listdir("test_images")
test_df = pd.DataFrame({'file_name': test_filenames})

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_efficientnet_v2
)
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory="test_images",
    x_col='file_name',
    y_col=None,
    target_size=(224, 224),
    batch_size=20,
    class_mode=None,
    shuffle=False
)

predictions = best_model.predict(
    test_generator,
    steps=len(test_generator),
    verbose=1
)

predicted_classes = np.argmax(predictions, axis=1)

submission = pd.DataFrame({
    'file_name': test_filenames,
    'label_id': predicted_classes
})

# ソート用にファイル名の数字部分を抽出
submission['file_num'] = submission['file_name'].str.extract(r'(\d+)').astype(int)
submission = submission.sort_values(by='file_num').drop(columns='file_num')

output_filename = f'{base_dir}/submission_efficientnetv2l_224_0405_r0.tsv'
submission.to_csv(output_filename, sep='\t', index=False, header=False)
print(f"提出用ファイル {output_filename} を作成しました。")
# Out:
# Mounted at /content/drive
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 19.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=e23561286d48961f9d6f0d6c98e64a6a25ed3bce3557c16acc33f27d91fb8ef8
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3
# Num GPUs Available:  1
# Mixed Precision Policy:  <DTypePolicy "mixed_float16">
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Found 4000 validated image filenames belonging to 10 classes.
# Found 1000 validated image filenames belonging to 10 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 208s 478ms/step - accuracy: 0.4537 - loss: 1.8431 - val_accuracy: 0.9500 - val_loss: 0.9437 - learning_rate: 1.0000e-04
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 123s 377ms/step - accuracy: 0.7371 - loss: 1.2012 - val_accuracy: 0.9550 - val_loss: 0.6830 - learning_rate: 1.0000e-04
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 73s 365ms/step - accuracy: 0.7743 - loss: 1.1051 - val_accuracy: 0.9540 - val_loss: 0.6802 - learning_rate: 1.0000e-04
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 341ms/step - accuracy: 0.7780 - loss: 1.0835 - val_accuracy: 0.9530 - val_loss: 0.6820 - learning_rate: 1.0000e-04
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 88s 371ms/step - accuracy: 0.7835 - loss: 1.0756 - val_accuracy: 0.9600 - val_loss: 0.6702 - learning_rate: 1.0000e-04
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 75s 337ms/step - accuracy: 0.7949 - loss: 1.0369 - val_accuracy: 0.9590 - val_loss: 0.6751 - learning_rate: 1.0000e-04
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 341ms/step - accuracy: 0.7903 - loss: 1.0375 - val_accuracy: 0.9560 - val_loss: 0.6728 - learning_rate: 1.0000e-04
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 67s 335ms/step - accuracy: 0.8260 - loss: 0.9865 - val_accuracy: 0.9570 - val_loss: 0.6779 - learning_rate: 1.0000e-04
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 343ms/step - accuracy: 0.8058 - loss: 1.0229 - val_accuracy: 0.9570 - val_loss: 0.6752 - learning_rate: 1.0000e-05
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 79s 327ms/step - accuracy: 0.8000 - loss: 1.0154 - val_accuracy: 0.9580 - val_loss: 0.6711 - learning_rate: 1.0000e-05
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 79s 395ms/step - accuracy: 0.8177 - loss: 0.9858 - val_accuracy: 0.9580 - val_loss: 0.6687 - learning_rate: 1.0000e-05
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 76s 365ms/step - accuracy: 0.8204 - loss: 0.9932 - val_accuracy: 0.9590 - val_loss: 0.6670 - learning_rate: 1.0000e-05
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 80s 354ms/step - accuracy: 0.8119 - loss: 0.9976 - val_accuracy: 0.9600 - val_loss: 0.6653 - learning_rate: 1.0000e-05
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 73s 367ms/step - accuracy: 0.8089 - loss: 0.9861 - val_accuracy: 0.9610 - val_loss: 0.6640 - learning_rate: 1.0000e-05
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 66s 331ms/step - accuracy: 0.8073 - loss: 1.0005 - val_accuracy: 0.9600 - val_loss: 0.6642 - learning_rate: 1.0000e-05
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 334ms/step - accuracy: 0.8190 - loss: 0.9761 - val_accuracy: 0.9600 - val_loss: 0.6651 - learning_rate: 1.0000e-05
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 84s 343ms/step - accuracy: 0.8199 - loss: 0.9801 - val_accuracy: 0.9600 - val_loss: 0.6649 - learning_rate: 1.0000e-05
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 94s 402ms/step - accuracy: 0.8227 - loss: 0.9736 - val_accuracy: 0.9600 - val_loss: 0.6623 - learning_rate: 1.0000e-05
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 76s 379ms/step - accuracy: 0.8033 - loss: 1.0083 - val_accuracy: 0.9620 - val_loss: 0.6611 - learning_rate: 1.0000e-05
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 78s 358ms/step - accuracy: 0.8030 - loss: 1.0038 - val_accuracy: 0.9610 - val_loss: 0.6603 - learning_rate: 1.0000e-05
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 86s 380ms/step - accuracy: 0.8136 - loss: 0.9675 - val_accuracy: 0.9600 - val_loss: 0.6592 - learning_rate: 1.0000e-05
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 383ms/step - accuracy: 0.8135 - loss: 0.9934 - val_accuracy: 0.9600 - val_loss: 0.6581 - learning_rate: 1.0000e-05
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 67s 333ms/step - accuracy: 0.8233 - loss: 0.9711 - val_accuracy: 0.9620 - val_loss: 0.6582 - learning_rate: 1.0000e-05
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 412ms/step - accuracy: 0.8169 - loss: 0.9914 - val_accuracy: 0.9620 - val_loss: 0.6580 - learning_rate: 1.0000e-05
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 135s 376ms/step - accuracy: 0.8179 - loss: 0.9609 - val_accuracy: 0.9600 - val_loss: 0.6562 - learning_rate: 1.0000e-05
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 73s 331ms/step - accuracy: 0.8181 - loss: 0.9672 - val_accuracy: 0.9600 - val_loss: 0.6568 - learning_rate: 1.0000e-05
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 73s 363ms/step - accuracy: 0.8278 - loss: 0.9613 - val_accuracy: 0.9600 - val_loss: 0.6561 - learning_rate: 1.0000e-05
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 80s 400ms/step - accuracy: 0.8321 - loss: 0.9574 - val_accuracy: 0.9610 - val_loss: 0.6556 - learning_rate: 1.0000e-05
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 342ms/step - accuracy: 0.8372 - loss: 0.9456 - val_accuracy: 0.9600 - val_loss: 0.6561 - learning_rate: 1.0000e-05
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 341ms/step - accuracy: 0.8510 - loss: 0.9177 - val_accuracy: 0.9620 - val_loss: 0.6561 - learning_rate: 1.0000e-05
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 91s 386ms/step - accuracy: 0.8215 - loss: 0.9791 - val_accuracy: 0.9610 - val_loss: 0.6552 - learning_rate: 1.0000e-05
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 342ms/step - accuracy: 0.8266 - loss: 0.9398 - val_accuracy: 0.9630 - val_loss: 0.6564 - learning_rate: 1.0000e-05
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 72s 362ms/step - accuracy: 0.8122 - loss: 0.9822 - val_accuracy: 0.9620 - val_loss: 0.6536 - learning_rate: 1.0000e-05
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 81s 403ms/step - accuracy: 0.8234 - loss: 0.9681 - val_accuracy: 0.9590 - val_loss: 0.6532 - learning_rate: 1.0000e-05
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 338ms/step - accuracy: 0.8201 - loss: 0.9638 - val_accuracy: 0.9580 - val_loss: 0.6541 - learning_rate: 1.0000e-05
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 86s 356ms/step - accuracy: 0.8243 - loss: 0.9630 - val_accuracy: 0.9590 - val_loss: 0.6544 - learning_rate: 1.0000e-05
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 78s 335ms/step - accuracy: 0.8279 - loss: 0.9521 - val_accuracy: 0.9590 - val_loss: 0.6540 - learning_rate: 1.0000e-05
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 95s 400ms/step - accuracy: 0.8158 - loss: 0.9646 - val_accuracy: 0.9590 - val_loss: 0.6530 - learning_rate: 1.0000e-05
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 79s 394ms/step - accuracy: 0.8334 - loss: 0.9387 - val_accuracy: 0.9600 - val_loss: 0.6527 - learning_rate: 1.0000e-05
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 394ms/step - accuracy: 0.8428 - loss: 0.9314 - val_accuracy: 0.9610 - val_loss: 0.6524 - learning_rate: 1.0000e-05
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 72s 346ms/step - accuracy: 0.8277 - loss: 0.9455 - val_accuracy: 0.9590 - val_loss: 0.6536 - learning_rate: 1.0000e-05
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 81s 341ms/step - accuracy: 0.8423 - loss: 0.9273 - val_accuracy: 0.9600 - val_loss: 0.6526 - learning_rate: 1.0000e-05
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 75s 375ms/step - accuracy: 0.8348 - loss: 0.9352 - val_accuracy: 0.9610 - val_loss: 0.6506 - learning_rate: 1.0000e-05
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 78s 355ms/step - accuracy: 0.8344 - loss: 0.9498 - val_accuracy: 0.9610 - val_loss: 0.6526 - learning_rate: 1.0000e-05
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 79s 343ms/step - accuracy: 0.8365 - loss: 0.9372 - val_accuracy: 0.9620 - val_loss: 0.6518 - learning_rate: 1.0000e-05
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 345ms/step - accuracy: 0.8297 - loss: 0.9402 - val_accuracy: 0.9630 - val_loss: 0.6517 - learning_rate: 1.0000e-05
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 67s 337ms/step - accuracy: 0.8261 - loss: 0.9515 - val_accuracy: 0.9610 - val_loss: 0.6517 - learning_rate: 1.0000e-05
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 84s 349ms/step - accuracy: 0.8370 - loss: 0.9302 - val_accuracy: 0.9630 - val_loss: 0.6508 - learning_rate: 1.0000e-05
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 81s 342ms/step - accuracy: 0.8351 - loss: 0.9454 - val_accuracy: 0.9620 - val_loss: 0.6507 - learning_rate: 1.0000e-05
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 83s 346ms/step - accuracy: 0.8327 - loss: 0.9354 - val_accuracy: 0.9620 - val_loss: 0.6512 - learning_rate: 1.0000e-05
# Epoch 1/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 225s 504ms/step - accuracy: 0.8180 - loss: 0.9789 - val_accuracy: 0.9660 - val_loss: 0.6684 - learning_rate: 1.0000e-04
# Epoch 2/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - accuracy: 0.8378 - loss: 0.9591 - val_accuracy: 0.9670 - val_loss: 0.6407 - learning_rate: 1.0000e-04
# Epoch 3/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 353ms/step - accuracy: 0.8533 - loss: 0.8915 - val_accuracy: 0.9690 - val_loss: 0.6436 - learning_rate: 1.0000e-04
# Epoch 4/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 128s 585ms/step - accuracy: 0.8678 - loss: 0.8680 - val_accuracy: 0.9710 - val_loss: 0.6399 - learning_rate: 1.0000e-04
# Epoch 5/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 135s 550ms/step - accuracy: 0.8805 - loss: 0.8334 - val_accuracy: 0.9780 - val_loss: 0.6310 - learning_rate: 1.0000e-04
# Epoch 6/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 348ms/step - accuracy: 0.8922 - loss: 0.8191 - val_accuracy: 0.9670 - val_loss: 0.6418 - learning_rate: 1.0000e-04
# Epoch 7/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 129s 586ms/step - accuracy: 0.8981 - loss: 0.8029 - val_accuracy: 0.9770 - val_loss: 0.6297 - learning_rate: 1.0000e-04
# Epoch 8/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 139s 573ms/step - accuracy: 0.8846 - loss: 0.8145 - val_accuracy: 0.9770 - val_loss: 0.6234 - learning_rate: 1.0000e-04
# Epoch 9/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 99s 493ms/step - accuracy: 0.9151 - loss: 0.7721 - val_accuracy: 0.9740 - val_loss: 0.6174 - learning_rate: 1.0000e-04
# Epoch 10/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 346ms/step - accuracy: 0.9196 - loss: 0.7592 - val_accuracy: 0.9780 - val_loss: 0.6188 - learning_rate: 1.0000e-04
# Epoch 11/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 122s 548ms/step - accuracy: 0.9230 - loss: 0.7560 - val_accuracy: 0.9810 - val_loss: 0.6015 - learning_rate: 1.0000e-04
# Epoch 12/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 355ms/step - accuracy: 0.9217 - loss: 0.7417 - val_accuracy: 0.9810 - val_loss: 0.6105 - learning_rate: 1.0000e-04
# Epoch 13/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 83s 360ms/step - accuracy: 0.9327 - loss: 0.7277 - val_accuracy: 0.9790 - val_loss: 0.6108 - learning_rate: 1.0000e-04
# Epoch 14/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 363ms/step - accuracy: 0.9293 - loss: 0.7319 - val_accuracy: 0.9780 - val_loss: 0.6056 - learning_rate: 1.0000e-04
# Epoch 15/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 88s 440ms/step - accuracy: 0.9396 - loss: 0.7117 - val_accuracy: 0.9800 - val_loss: 0.5962 - learning_rate: 1.0000e-05
# Epoch 16/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 138s 418ms/step - accuracy: 0.9350 - loss: 0.7191 - val_accuracy: 0.9800 - val_loss: 0.5927 - learning_rate: 1.0000e-05
# Epoch 17/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 139s 405ms/step - accuracy: 0.9526 - loss: 0.6835 - val_accuracy: 0.9810 - val_loss: 0.5905 - learning_rate: 1.0000e-05
# Epoch 18/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 88s 435ms/step - accuracy: 0.9445 - loss: 0.6850 - val_accuracy: 0.9810 - val_loss: 0.5863 - learning_rate: 1.0000e-05
# Epoch 19/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 127s 359ms/step - accuracy: 0.9524 - loss: 0.6827 - val_accuracy: 0.9820 - val_loss: 0.5870 - learning_rate: 1.0000e-05
# Epoch 20/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 110s 499ms/step - accuracy: 0.9539 - loss: 0.6814 - val_accuracy: 0.9810 - val_loss: 0.5853 - learning_rate: 1.0000e-05
# Epoch 21/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 83s 413ms/step - accuracy: 0.9577 - loss: 0.6666 - val_accuracy: 0.9840 - val_loss: 0.5834 - learning_rate: 1.0000e-05
# Epoch 22/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 149s 447ms/step - accuracy: 0.9520 - loss: 0.6693 - val_accuracy: 0.9840 - val_loss: 0.5820 - learning_rate: 1.0000e-05
# Epoch 23/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 150s 485ms/step - accuracy: 0.9542 - loss: 0.6698 - val_accuracy: 0.9820 - val_loss: 0.5793 - learning_rate: 1.0000e-05
# Epoch 24/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 354ms/step - accuracy: 0.9651 - loss: 0.6694 - val_accuracy: 0.9840 - val_loss: 0.5814 - learning_rate: 1.0000e-05
# Epoch 25/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 82s 352ms/step - accuracy: 0.9568 - loss: 0.6775 - val_accuracy: 0.9820 - val_loss: 0.5807 - learning_rate: 1.0000e-05
# Epoch 26/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 109s 547ms/step - accuracy: 0.9575 - loss: 0.6618 - val_accuracy: 0.9820 - val_loss: 0.5786 - learning_rate: 1.0000e-05
# Epoch 27/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - accuracy: 0.9599 - loss: 0.6579 - val_accuracy: 0.9820 - val_loss: 0.5778 - learning_rate: 1.0000e-05
# Epoch 28/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 354ms/step - accuracy: 0.9518 - loss: 0.6749 - val_accuracy: 0.9830 - val_loss: 0.5788 - learning_rate: 1.0000e-05
# Epoch 29/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 80s 345ms/step - accuracy: 0.9550 - loss: 0.6661 - val_accuracy: 0.9830 - val_loss: 0.5782 - learning_rate: 1.0000e-05
# Epoch 30/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 72s 357ms/step - accuracy: 0.9556 - loss: 0.6707 - val_accuracy: 0.9810 - val_loss: 0.5787 - learning_rate: 1.0000e-05
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 38s 82ms/step - accuracy: 0.9896 - loss: 0.5681
# Validation Loss: 0.5778
# Validation Accuracy: 0.9820
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step
# Found 8000 validated image filenames.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 53s 86ms/step
# 提出用ファイル /content/drive/MyDrive/Colab Notebooks/AI_2024_S2/submission_efficientnetv2l_224_0405_r0.tsv を作成しました。
