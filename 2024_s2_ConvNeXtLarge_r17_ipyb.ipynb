# %% [markdown]
# <a href="https://colab.research.google.com/github/moroq2/AI-2024-S2/blob/main/2024_s2_ConvNeXtLarge_r17_ipyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #画像データに対して、10種類のラベルの1つを割り当てるモデルを作成していただきます
#
# 画像認識とは、画像および動画から文字や顔などのオブジェクトや特徴を認識し検出するパターン認識技術の一分野です。特に画像に対してラベルを割り当てる画像分類は画像認識の領域においてポピュラーな研究分野となっていて、最近は深層学習が圧倒的な精度を達成しています。今回は犬や猫などの動物や車などの無機物が写った画像に対して10種類のラベルから一つ割り当てる問題に挑戦していただきます。
#
# 本コンペを活用して、データ解析・モデル構築を体験してください。
#
# データ概要
#
# 課題種別：分類
# データ種別：画像
# 学習データサンプル数：5,000
# 画像の大きさ：96×96

# %%
# ========================================
# Google Colab 上で GPU を使用する想定
# ========================================

# 1. Google Drive をマウント
from google.colab import drive
drive.mount('/content/drive')

# 2. 日本語表示のためのライブラリをインストール＆インポート
# !pip install japanize_matplotlib
import japanize_matplotlib

# 3. GPUが利用可能か確認
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# 4. 混合精度学習(Mixed Precision)の設定
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')
print("Mixed Precision Policy: ", tf.keras.mixed_precision.global_policy())

# 5. ファイルパスの設定
base_dir = "/content/drive/MyDrive/Colab Notebooks/AI_2024_S2"

# 6. 必要なライブラリのインポート
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.convnext import ConvNeXtLarge, preprocess_input as preprocess_convnext
from tensorflow.keras.activations import swish
from tensorflow.keras.losses import CategoricalCrossentropy

# !pip install scikit-learn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# 7. データの準備（解凍＆ファイルコピー）
if not os.path.exists("train_images"):
    os.system(f"unzip -q '{base_dir}/train_images.zip'")
    os.system(f"unzip -q '{base_dir}/test_images.zip'")
    # !cp "{base_dir}/label_master.tsv" .
    # !cp "{base_dir}/sample_submit.tsv" .
    # !cp "{base_dir}/train_master.tsv" .

train_master = pd.read_csv('train_master.tsv', sep='\t')
label_master = pd.read_csv('label_master.tsv', sep='\t')
train_master['label_id'] = train_master['label_id'].astype(str)

# =========================================================
# 8. データ前処理＆学習・検証用ジェネレータの作成
#    （ラベル毎にバランス良くデータを分割する）
# =========================================================

def create_generators(preprocess_func, batch_size=50, target_size=(224, 224), test_size=0.2):
    """
    画像の基本的な前処理ジェネレータ（データ拡張あり）
    ラベルが均等になるように分割する
    """
    train_df, val_df = train_test_split(
        train_master,
        test_size=test_size,
        random_state=2,
        stratify=train_master['label_id']
    )

    # 学習用のImageDataGenerator（データ拡張を付与）
    datagen_train = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.2,
        zoom_range=[0.8, 1.2],
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.7, 1.3],
        channel_shift_range=50.0,
        fill_mode='reflect',
        preprocessing_function=preprocess_func
    )

    # バリデーション用のImageDataGenerator（データ拡張なし）
    datagen_val = ImageDataGenerator(
        preprocessing_function=preprocess_func
    )

    train_generator = datagen_train.flow_from_dataframe(
        dataframe=train_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=3
    )

    val_generator = datagen_val.flow_from_dataframe(
        dataframe=val_df,
        directory="train_images",
        x_col='file_name',
        y_col='label_id',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=4
    )

    return train_generator, val_generator, train_df, val_df

# =========================================================
# 9. モデル構築（ConvNeXtLarge + カスタム分類ヘッド）
#    （Swish活性化, BatchNormalization, Dropout採用）
# =========================================================

def build_convnext_model(input_shape=(224, 224, 3), num_classes=10, train_base=False):
    """
    ConvNeXtLarge をベースとした転移学習モデルの構築 (入力サイズ: 224x224)
    train_base=Falseならベースを凍結、Trueならファインチューニング可能
    """
    base_model = ConvNeXtLarge(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    # ベースモデルの凍結設定
    for layer in base_model.layers:
        layer.trainable = train_base

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(2048, activation=swish)(x)
    x = Dropout(0.4)(x)
    # 出力層はfloat32にキャスト（Mixed Precision環境下で安定動作のため）
    outputs = Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = Model(inputs=base_model.input, outputs=outputs)
    return model

# =========================================================
# 10. 損失関数を変更（Focal Loss → CategoricalCrossentropy）
#     ※ ラベル平滑化を適用
# =========================================================
loss_fn = CategoricalCrossentropy(label_smoothing=0.1)

# =========================================================
# 11. モデルコンパイル・初期学習
# =========================================================

# ジェネレータ作成（ConvNeXt用の前処理関数を指定）
train_gen, val_gen, train_df, val_df = create_generators(
    preprocess_func=preprocess_convnext,
    batch_size=20,
    target_size=(224, 224),
    test_size=0.2
)

# モデル構築（初期学習時はベースは凍結）
model = build_convnext_model(
    input_shape=(224, 224, 3),
    num_classes=10,
    train_base=False
)

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=2e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_convnextlarge_224.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=30,  # 初期学習のエポック数
    callbacks=callbacks
)

# =========================================================
# 11.5 Hard Example Mining (HEM) の実装（初期学習後）
# =========================================================

# --- パラメータ ---
HEM_THRESHOLD = 0.7   # 予測確率がこの値より低い場合をハード例とみなす
HEM_EPOCHS = 20       # ハード例を再学習する追加エポック

print(f"\n=== Hard Example Mining (1回目): threshold={HEM_THRESHOLD}, epochs={HEM_EPOCHS} ===\n")

# 学習済みモデルで train_df 全体を推論するため、shuffle=Falseでジェネレータを用意
datagen_no_aug = ImageDataGenerator(preprocessing_function=preprocess_convnext)
train_df_for_predict = datagen_no_aug.flow_from_dataframe(
    dataframe=train_df,
    directory="train_images",
    x_col='file_name',
    y_col='label_id',
    target_size=(224,224),
    batch_size=20,
    class_mode='categorical',
    shuffle=False
)

# 推論実行
preds = model.predict(train_df_for_predict, steps=len(train_df_for_predict), verbose=1)
true_classes = train_df_for_predict.classes
pred_classes = np.argmax(preds, axis=1)

# 誤分類 + (正解だが確信度が低い) サンプルを収集
hard_indices = []
for i in range(len(preds)):
    predicted_label = pred_classes[i]
    true_label = true_classes[i]
    confidence = preds[i, predicted_label]

    # 条件1: 誤分類
    is_misclassified = (predicted_label != true_label)
    # 条件2: 予測確率が一定閾値未満
    is_low_confidence = (confidence < HEM_THRESHOLD)

    if is_misclassified or is_low_confidence:
        hard_indices.append(i)

print(f"Hard Example Mining (1回目): {len(hard_indices)} サンプルが抽出されました。")

# ハードサンプルのみをDataFrame化
hard_samples_df = train_df.iloc[hard_indices]

# ハードサンプル用ジェネレータ
hard_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    preprocessing_function=preprocess_convnext
)

hard_gen = hard_datagen.flow_from_dataframe(
    dataframe=hard_samples_df,
    directory="train_images",
    x_col='file_name',
    y_col='label_id',
    target_size=(224,224),
    batch_size=20,
    class_mode='categorical',
    shuffle=True,
    classes=[str(i) for i in range(10)]  # ← ここで全クラスを指定する
)

# HEM用の追加学習
history_hem = model.fit(
    hard_gen,
    steps_per_epoch=hard_gen.samples // hard_gen.batch_size,
    epochs=HEM_EPOCHS,
    verbose=1
)

# =========================================================
# 12. ファインチューニング（最後の数十層を解凍）
# =========================================================
for layer in model.layers[-50:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),
    loss=loss_fn,
    metrics=['accuracy']
)

fine_tune_callbacks = [
    EarlyStopping(monitor='val_loss', patience=9, restore_best_weights=True),
    ModelCheckpoint('best_model_convnextlarge_224_finetuned.keras', monitor='val_loss', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-5)
]

history_fine = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // train_gen.batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // val_gen.batch_size,
    epochs=50,
    callbacks=fine_tune_callbacks
)

plt.figure()
plt.plot(history_fine.history['loss'], label='train_loss')
plt.plot(history_fine.history['val_loss'], label='val_loss')
plt.title('ファインチューニング: 損失推移')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_fine.history['accuracy'], label='train_accuracy')
plt.plot(history_fine.history['val_accuracy'], label='val_accuracy')
plt.title('ファインチューニング: 精度推移')
plt.legend()
plt.show()

# =========================================================
# 12.6 ヒートマップ表示＆Accuracy
# =========================================================
final_model = load_model(
    'best_model_convnextlarge_224_finetuned.keras',
    custom_objects={'swish': swish}
)

val_gen.reset()
val_loss, val_accuracy = final_model.evaluate(val_gen, steps=len(val_gen), verbose=1)
print(f"\n=== バリデーション評価 ===")
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")

val_gen.reset()
val_predictions = final_model.predict(val_gen, steps=len(val_gen), verbose=1)
val_predicted_classes = np.argmax(val_predictions, axis=1)
true_classes_final = val_gen.classes

cm_final = confusion_matrix(true_classes_final, val_predicted_classes)

plt.figure(figsize=(8, 6))
plt.imshow(cm_final, interpolation='nearest', cmap='Blues')
plt.title('バリデーションデータにおける混同行列')
plt.colorbar()

num_classes = 10
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, [str(i) for i in range(num_classes)], rotation=45)
plt.yticks(tick_marks, [str(i) for i in range(num_classes)])

for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, str(cm_final[i, j]),
                 ha='center', va='center', color='black')

plt.ylabel('正解ラベル')
plt.xlabel('予測ラベル')
plt.tight_layout()
plt.show()

# =========================================================
# 13. テストデータでの推論
#    => 最終的に HEM2 後のモデルを使用する
# =========================================================

test_filenames = os.listdir("test_images")
test_df = pd.DataFrame({'file_name': test_filenames})

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_convnext
)
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory="test_images",
    x_col='file_name',
    y_col=None,
    target_size=(224,224),
    batch_size=20,
    class_mode=None,
    shuffle=False
)

predictions = final_model.predict(
    test_generator,
    steps=len(test_generator),
    verbose=1
)

predicted_classes = np.argmax(predictions, axis=1)

submission = pd.DataFrame({
    'file_name': test_filenames,
    'label_id': predicted_classes
})

# ソート用にファイル名の数字部分を抽出
submission['file_num'] = submission['file_name'].str.extract(r'(\d+)').astype(int)
submission = submission.sort_values(by='file_num').drop(columns='file_num')

output_filename = f'{base_dir}/submission_convnextlarge_224_hem2_0410_r0.tsv'
submission.to_csv(output_filename, sep='\t', index=False, header=False)
print(f"提出用ファイル {output_filename} を作成しました。")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: japanize_matplotlib in /usr/local/lib/python3.11/dist-packages (1.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)
# Num GPUs Available:  1
# Mixed Precision Policy:  <DTypePolicy "mixed_float16">
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Found 4000 validated image filenames belonging to 10 classes.
# Found 1000 validated image filenames belonging to 10 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 99s 322ms/step - accuracy: 0.7294 - loss: 1.2059 - val_accuracy: 0.9870 - val_loss: 0.6172 - learning_rate: 2.0000e-04
# Epoch 2/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 261ms/step - accuracy: 0.8938 - loss: 0.8337 - val_accuracy: 0.9820 - val_loss: 0.6372 - learning_rate: 2.0000e-04
# Epoch 3/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 259ms/step - accuracy: 0.9090 - loss: 0.8206 - val_accuracy: 0.9790 - val_loss: 0.6480 - learning_rate: 2.0000e-04
# Epoch 4/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 262ms/step - accuracy: 0.9282 - loss: 0.7677 - val_accuracy: 0.9800 - val_loss: 0.6481 - learning_rate: 2.0000e-04
# Epoch 5/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 259ms/step - accuracy: 0.9356 - loss: 0.7428 - val_accuracy: 0.9820 - val_loss: 0.6281 - learning_rate: 2.0000e-05
# Epoch 6/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 260ms/step - accuracy: 0.9466 - loss: 0.7093 - val_accuracy: 0.9840 - val_loss: 0.6180 - learning_rate: 2.0000e-05
# Epoch 7/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 280ms/step - accuracy: 0.9475 - loss: 0.7031 - val_accuracy: 0.9830 - val_loss: 0.6117 - learning_rate: 2.0000e-05
# Epoch 8/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 260ms/step - accuracy: 0.9570 - loss: 0.6935 - val_accuracy: 0.9860 - val_loss: 0.6120 - learning_rate: 2.0000e-05
# Epoch 9/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 280ms/step - accuracy: 0.9526 - loss: 0.6913 - val_accuracy: 0.9850 - val_loss: 0.6098 - learning_rate: 2.0000e-05
# Epoch 10/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 281ms/step - accuracy: 0.9574 - loss: 0.6851 - val_accuracy: 0.9840 - val_loss: 0.6077 - learning_rate: 2.0000e-05
# Epoch 11/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 279ms/step - accuracy: 0.9545 - loss: 0.6875 - val_accuracy: 0.9850 - val_loss: 0.6044 - learning_rate: 2.0000e-05
# Epoch 12/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 260ms/step - accuracy: 0.9584 - loss: 0.6716 - val_accuracy: 0.9850 - val_loss: 0.6048 - learning_rate: 2.0000e-05
# Epoch 13/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 280ms/step - accuracy: 0.9597 - loss: 0.6720 - val_accuracy: 0.9840 - val_loss: 0.6021 - learning_rate: 2.0000e-05
# Epoch 14/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 262ms/step - accuracy: 0.9674 - loss: 0.6619 - val_accuracy: 0.9830 - val_loss: 0.6034 - learning_rate: 2.0000e-05
# Epoch 15/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 279ms/step - accuracy: 0.9692 - loss: 0.6632 - val_accuracy: 0.9830 - val_loss: 0.6020 - learning_rate: 2.0000e-05
# Epoch 16/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 282ms/step - accuracy: 0.9670 - loss: 0.6595 - val_accuracy: 0.9840 - val_loss: 0.5997 - learning_rate: 2.0000e-05
# Epoch 17/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 278ms/step - accuracy: 0.9647 - loss: 0.6628 - val_accuracy: 0.9850 - val_loss: 0.5992 - learning_rate: 2.0000e-05
# Epoch 18/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 281ms/step - accuracy: 0.9567 - loss: 0.6686 - val_accuracy: 0.9840 - val_loss: 0.5971 - learning_rate: 2.0000e-05
# Epoch 19/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 279ms/step - accuracy: 0.9626 - loss: 0.6642 - val_accuracy: 0.9840 - val_loss: 0.5966 - learning_rate: 2.0000e-05
# Epoch 20/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 284ms/step - accuracy: 0.9612 - loss: 0.6651 - val_accuracy: 0.9850 - val_loss: 0.5966 - learning_rate: 2.0000e-05
# Epoch 21/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 264ms/step - accuracy: 0.9596 - loss: 0.6663 - val_accuracy: 0.9860 - val_loss: 0.5989 - learning_rate: 2.0000e-05
# Epoch 22/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 259ms/step - accuracy: 0.9578 - loss: 0.6661 - val_accuracy: 0.9840 - val_loss: 0.5972 - learning_rate: 2.0000e-05
# Epoch 23/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 281ms/step - accuracy: 0.9614 - loss: 0.6593 - val_accuracy: 0.9850 - val_loss: 0.5957 - learning_rate: 1.0000e-05
# Epoch 24/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 283ms/step - accuracy: 0.9690 - loss: 0.6528 - val_accuracy: 0.9840 - val_loss: 0.5945 - learning_rate: 1.0000e-05
# Epoch 25/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 56s 282ms/step - accuracy: 0.9733 - loss: 0.6505 - val_accuracy: 0.9840 - val_loss: 0.5930 - learning_rate: 1.0000e-05
# Epoch 26/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 285ms/step - accuracy: 0.9692 - loss: 0.6511 - val_accuracy: 0.9850 - val_loss: 0.5914 - learning_rate: 1.0000e-05
# Epoch 27/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 264ms/step - accuracy: 0.9724 - loss: 0.6443 - val_accuracy: 0.9850 - val_loss: 0.5924 - learning_rate: 1.0000e-05
# Epoch 28/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - accuracy: 0.9648 - loss: 0.6498 - val_accuracy: 0.9850 - val_loss: 0.5922 - learning_rate: 1.0000e-05
# Epoch 29/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 57s 283ms/step - accuracy: 0.9679 - loss: 0.6501 - val_accuracy: 0.9850 - val_loss: 0.5906 - learning_rate: 1.0000e-05
# Epoch 30/30
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 261ms/step - accuracy: 0.9711 - loss: 0.6468 - val_accuracy: 0.9850 - val_loss: 0.5909 - learning_rate: 1.0000e-05
#
# === Hard Example Mining (1回目): threshold=0.7, epochs=20 ===
#
# Found 4000 validated image filenames belonging to 10 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 55ms/step
# Hard Example Mining (1回目): 60 サンプルが抽出されました。
# Found 60 validated image filenames belonging to 10 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.7354 - loss: 1.0582
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.7292 - loss: 1.0076
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.8396 - loss: 0.9053
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.7833 - loss: 0.9862
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.8229 - loss: 0.9612
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.9417 - loss: 0.7825
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.8729 - loss: 0.8399
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.9500 - loss: 0.7434
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.8958 - loss: 0.8248
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.9167 - loss: 0.7819
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.9292 - loss: 0.7291
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.9354 - loss: 0.7262
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.9729 - loss: 0.6858
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0.9833 - loss: 0.6723
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.9917 - loss: 0.6998
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.9729 - loss: 0.6894
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.9771 - loss: 0.6645
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.9917 - loss: 0.6649
# Epoch 19/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.9583 - loss: 0.7235
# Epoch 20/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - accuracy: 0.9312 - loss: 0.6926
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 118s 383ms/step - accuracy: 0.9488 - loss: 0.7002 - val_accuracy: 0.9790 - val_loss: 0.6155 - learning_rate: 1.0000e-04
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9598 - loss: 0.6715 - val_accuracy: 0.9810 - val_loss: 0.6168 - learning_rate: 1.0000e-04
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 350ms/step - accuracy: 0.9725 - loss: 0.6594 - val_accuracy: 0.9760 - val_loss: 0.5996 - learning_rate: 1.0000e-04
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 73s 363ms/step - accuracy: 0.9753 - loss: 0.6363 - val_accuracy: 0.9850 - val_loss: 0.5914 - learning_rate: 1.0000e-04
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 350ms/step - accuracy: 0.9853 - loss: 0.6187 - val_accuracy: 0.9850 - val_loss: 0.5811 - learning_rate: 1.0000e-04
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 72s 361ms/step - accuracy: 0.9846 - loss: 0.6133 - val_accuracy: 0.9850 - val_loss: 0.5807 - learning_rate: 1.0000e-04
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9860 - loss: 0.6086 - val_accuracy: 0.9840 - val_loss: 0.5830 - learning_rate: 1.0000e-04
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 354ms/step - accuracy: 0.9868 - loss: 0.5974 - val_accuracy: 0.9840 - val_loss: 0.5673 - learning_rate: 1.0000e-04
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9852 - loss: 0.5946 - val_accuracy: 0.9810 - val_loss: 0.5702 - learning_rate: 1.0000e-04
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 349ms/step - accuracy: 0.9911 - loss: 0.5854 - val_accuracy: 0.9810 - val_loss: 0.5669 - learning_rate: 1.0000e-04
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 74s 369ms/step - accuracy: 0.9887 - loss: 0.5795 - val_accuracy: 0.9870 - val_loss: 0.5601 - learning_rate: 1.0000e-04
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9928 - loss: 0.5720 - val_accuracy: 0.9860 - val_loss: 0.5658 - learning_rate: 1.0000e-04
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.9919 - loss: 0.5718 - val_accuracy: 0.9860 - val_loss: 0.5623 - learning_rate: 1.0000e-04
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 347ms/step - accuracy: 0.9897 - loss: 0.5713 - val_accuracy: 0.9870 - val_loss: 0.5566 - learning_rate: 1.0000e-04
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 295ms/step - accuracy: 0.9942 - loss: 0.5667 - val_accuracy: 0.9880 - val_loss: 0.5576 - learning_rate: 1.0000e-04
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 72s 361ms/step - accuracy: 0.9944 - loss: 0.5628 - val_accuracy: 0.9880 - val_loss: 0.5509 - learning_rate: 1.0000e-04
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 72s 360ms/step - accuracy: 0.9912 - loss: 0.5626 - val_accuracy: 0.9890 - val_loss: 0.5489 - learning_rate: 1.0000e-04
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 295ms/step - accuracy: 0.9962 - loss: 0.5495 - val_accuracy: 0.9880 - val_loss: 0.5511 - learning_rate: 1.0000e-04
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9952 - loss: 0.5513 - val_accuracy: 0.9840 - val_loss: 0.5534 - learning_rate: 1.0000e-04
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 354ms/step - accuracy: 0.9966 - loss: 0.5494 - val_accuracy: 0.9840 - val_loss: 0.5437 - learning_rate: 1.0000e-04
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 348ms/step - accuracy: 0.9957 - loss: 0.5468 - val_accuracy: 0.9900 - val_loss: 0.5400 - learning_rate: 1.0000e-04
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9954 - loss: 0.5481 - val_accuracy: 0.9870 - val_loss: 0.5445 - learning_rate: 1.0000e-04
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.9976 - loss: 0.5414 - val_accuracy: 0.9870 - val_loss: 0.5418 - learning_rate: 1.0000e-04
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 295ms/step - accuracy: 0.9980 - loss: 0.5403 - val_accuracy: 0.9870 - val_loss: 0.5410 - learning_rate: 1.0000e-04
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 348ms/step - accuracy: 0.9987 - loss: 0.5331 - val_accuracy: 0.9870 - val_loss: 0.5348 - learning_rate: 1.0000e-05
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 351ms/step - accuracy: 0.9982 - loss: 0.5303 - val_accuracy: 0.9870 - val_loss: 0.5337 - learning_rate: 1.0000e-05
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 354ms/step - accuracy: 0.9969 - loss: 0.5305 - val_accuracy: 0.9860 - val_loss: 0.5328 - learning_rate: 1.0000e-05
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9988 - loss: 0.5282 - val_accuracy: 0.9870 - val_loss: 0.5331 - learning_rate: 1.0000e-05
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9994 - loss: 0.5267 - val_accuracy: 0.9870 - val_loss: 0.5335 - learning_rate: 1.0000e-05
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 292ms/step - accuracy: 0.9988 - loss: 0.5285 - val_accuracy: 0.9860 - val_loss: 0.5333 - learning_rate: 1.0000e-05
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 349ms/step - accuracy: 0.9978 - loss: 0.5290 - val_accuracy: 0.9870 - val_loss: 0.5328 - learning_rate: 1.0000e-05
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 351ms/step - accuracy: 0.9989 - loss: 0.5253 - val_accuracy: 0.9860 - val_loss: 0.5324 - learning_rate: 1.0000e-05
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9968 - loss: 0.5289 - val_accuracy: 0.9870 - val_loss: 0.5325 - learning_rate: 1.0000e-05
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 349ms/step - accuracy: 0.9983 - loss: 0.5275 - val_accuracy: 0.9860 - val_loss: 0.5313 - learning_rate: 1.0000e-05
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9989 - loss: 0.5250 - val_accuracy: 0.9880 - val_loss: 0.5322 - learning_rate: 1.0000e-05
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 352ms/step - accuracy: 0.9984 - loss: 0.5252 - val_accuracy: 0.9880 - val_loss: 0.5313 - learning_rate: 1.0000e-05
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 295ms/step - accuracy: 0.9988 - loss: 0.5250 - val_accuracy: 0.9860 - val_loss: 0.5314 - learning_rate: 1.0000e-05
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9985 - loss: 0.5235 - val_accuracy: 0.9870 - val_loss: 0.5319 - learning_rate: 1.0000e-05
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 349ms/step - accuracy: 0.9993 - loss: 0.5251 - val_accuracy: 0.9870 - val_loss: 0.5310 - learning_rate: 1.0000e-05
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 351ms/step - accuracy: 0.9996 - loss: 0.5231 - val_accuracy: 0.9870 - val_loss: 0.5306 - learning_rate: 1.0000e-05
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9989 - loss: 0.5231 - val_accuracy: 0.9860 - val_loss: 0.5316 - learning_rate: 1.0000e-05
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9980 - loss: 0.5251 - val_accuracy: 0.9870 - val_loss: 0.5316 - learning_rate: 1.0000e-05
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9993 - loss: 0.5221 - val_accuracy: 0.9860 - val_loss: 0.5317 - learning_rate: 1.0000e-05
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9976 - loss: 0.5245 - val_accuracy: 0.9860 - val_loss: 0.5323 - learning_rate: 1.0000e-05
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 295ms/step - accuracy: 0.9995 - loss: 0.5203 - val_accuracy: 0.9860 - val_loss: 0.5323 - learning_rate: 1.0000e-05
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 60s 297ms/step - accuracy: 0.9999 - loss: 0.5197 - val_accuracy: 0.9860 - val_loss: 0.5319 - learning_rate: 1.0000e-05
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 293ms/step - accuracy: 0.9996 - loss: 0.5202 - val_accuracy: 0.9870 - val_loss: 0.5327 - learning_rate: 1.0000e-05
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 59s 294ms/step - accuracy: 0.9998 - loss: 0.5209 - val_accuracy: 0.9870 - val_loss: 0.5312 - learning_rate: 1.0000e-05
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 74s 369ms/step - accuracy: 0.9992 - loss: 0.5199 - val_accuracy: 0.9860 - val_loss: 0.5306 - learning_rate: 1.0000e-05
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 71s 356ms/step - accuracy: 0.9981 - loss: 0.5212 - val_accuracy: 0.9880 - val_loss: 0.5304 - learning_rate: 1.0000e-05
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.9856 - loss: 0.5353
#
# === バリデーション評価 ===
# Validation Loss: 0.5304
# Validation Accuracy: 0.9880
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step
# Found 8000 validated image filenames.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 28s 55ms/step
# 提出用ファイル /content/drive/MyDrive/Colab Notebooks/AI_2024_S2/submission_convnextlarge_224_hem2_0410_r0.tsv を作成しました。
