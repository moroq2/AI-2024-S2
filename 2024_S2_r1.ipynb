# %% [markdown]
# <a href="https://colab.research.google.com/github/moroq2/AI-2024-S2/blob/main/2024_S2_r1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #画像データに対して、10種類のラベルの1つを割り当てるモデルを作成していただきます
#
# 画像認識とは、画像および動画から文字や顔などのオブジェクトや特徴を認識し検出するパターン認識技術の一分野です。特に画像に対してラベルを割り当てる画像分類は画像認識の領域においてポピュラーな研究分野となっていて、最近は深層学習が圧倒的な精度を達成しています。今回は犬や猫などの動物や車などの無機物が写った画像に対して10種類のラベルから一つ割り当てる問題に挑戦していただきます。
#
# 本コンペを活用して、データ解析・モデル構築を体験してください。
#
# データ概要
#
# 課題種別：分類
# データ種別：画像
# 学習データサンプル数：5,000
# 画像の大きさ：96×96

# %%
# Google Driveをマウント
from google.colab import drive
drive.mount('/content/drive')

# ファイルパスの設定
base_dir = "/content/drive/MyDrive/Colab Notebooks/AI_2024_S2"

# GPUが利用可能か確認（GPUが使える場合は1以上が表示されます）
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# 必要なライブラリのインポート
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf

from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# -----------------------------------------------
# 1. 学習用マスタファイルとラベルファイルの読み込み
# -----------------------------------------------
train_master = pd.read_csv(f'{base_dir}/train_master.tsv', sep='\t')
label_master = pd.read_csv(f'{base_dir}/label_master.tsv', sep='\t')

# flow_from_dataframeでクラスとして認識させるため、'label_id'列を文字列型に変換
train_master['label_id'] = train_master['label_id'].astype(str)

# データ確認
print("train_masterの先頭:")
print(train_master.head())
print("\nlabel_masterの先頭:")
print(label_master.head())

# -----------------------------------------------
# 2. データ前処理とデータ拡張
# -----------------------------------------------
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2  # 学習データの20%を検証用に分割
)

datagen_val = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = datagen_train.flow_from_dataframe(
    dataframe=train_master,
    directory=f'{base_dir}/train_images',  # 修正済み: f文字列
    x_col='file_name',
    y_col='label_id',
    target_size=(96, 96),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)

val_generator = datagen_val.flow_from_dataframe(
    dataframe=train_master,
    directory=f'{base_dir}/train_images',  # 修正済み: f文字列
    x_col='file_name',
    y_col='label_id',
    target_size=(96, 96),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=42
)

# -----------------------------------------------
# 3. CNNモデルの構築
# -----------------------------------------------
def build_improved_cnn(input_shape=(96,96,3), num_classes=10):
    model = models.Sequential([
        # 推奨されるInputレイヤーの明示
        tf.keras.Input(shape=input_shape),

        # --- Block 1 ---
        layers.Conv2D(32, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),  # 出力: (48,48,32)

        # --- Block 2 ---
        layers.Conv2D(64, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),  # 出力: (24,24,64)

        # --- Block 3 ---
        layers.Conv2D(128, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),  # 出力: (12,12,128)

        # --- Block 4 ---
        layers.Conv2D(256, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(256, (3,3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2,2)),  # 出力: (6,6,256)

        layers.Flatten(),

        # 全結合層
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),

        layers.Dense(num_classes, activation='softmax'),
    ])

    # optimizer も適宜調整
    # learning_rateを少し小さめにすると安定しやすい例
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# 上記モデルを使って学習するコード例
model = build_improved_cnn(input_shape=(96,96,3), num_classes=10)
model.summary()

# -----------------------------------------------
# 4. モデルの学習
# -----------------------------------------------
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)
]

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    epochs=50,
    callbacks=callbacks
)

# 学習履歴のグラフを作成
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('損失の推移')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('精度の推移')
plt.legend()
plt.show()

# -----------------------------------------------
# 5. テストデータでの推論と提出ファイルの作成
# -----------------------------------------------
test_filenames = os.listdir(f'{base_dir}/test_images')
test_df = pd.DataFrame({'file_name': test_filenames})

test_datagen = ImageDataGenerator(rescale=1./255)

# ★ ここを修正して f'{base_dir}/test_images' とする
test_generator = test_datagen.flow_from_dataframe(
    test_df,
    directory=f'{base_dir}/test_images',  # 修正済み
    x_col='file_name',
    y_col=None,
    target_size=(96,96),
    batch_size=32,
    class_mode=None,
    shuffle=False
)

# テスト画像に対する予測を実施
predictions = model.predict(test_generator, steps=len(test_generator), verbose=1)
predicted_classes = np.argmax(predictions, axis=1)

# TSV形式の提出用ファイルを作成
submission = pd.DataFrame({'file_name': test_filenames, 'label_id': predicted_classes})
submission.to_csv(f'{base_dir}/submission2025_311_r0.tsv', sep='\t', index=False, header=False)
print("提出用ファイル submission.tsv を作成しました。")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Num GPUs Available:  1
# train_masterの先頭:
#      file_name label_id
# 0  train_0.jpg        1
# 1  train_1.jpg        5
# 2  train_2.jpg        1
# 3  train_3.jpg        6
# 4  train_4.jpg        3
#
# label_masterの先頭:
#    label_id label_name
# 0         0   airplane
# 1         1       bird
# 2         2        car
# 3         3        cat
# 4         4       deer
# Found 4000 validated image filenames belonging to 10 classes.
# Found 1000 validated image filenames belonging to 10 classes.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# ...
